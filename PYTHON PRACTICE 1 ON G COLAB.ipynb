# %% [markdown]
# <a href="https://colab.research.google.com/github/Emmanuel-Igathe/DWARFINDER/blob/main/PYTHON%20PRACTICE%201%20ON%20G%20COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 + 1
# Out:
# 2

# %%
1 + 10
# Out:
# 11

# %%
name = "Manu"
print(name)
# Out:
# Manu

# %%
name = "Wangare"
print(type(name))
# Out:
# <class 'str'>

# %%
name = input("Enter your name:")
age = input("Please enter your age:")
print("Hello", name ,"Your age is ", age ,"years old")
# Out:
# Enter your name:manu
# Please enter your age:22
# Hello manu Your age is  22 years old

# %%
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the 2nd number:"))
print(num1 + num2)
print(num1 * num2)
print(num1 // num2)
print(num1 / num2)
print(num1 > num2)
# Out:
# Enter the first number:10
# Enter the 2nd number:20
# 30
# 200
# 0
# 0.5
# False

# %%
print("my" ,"name","is","Igathe", sep = "?")
# Out:
# my?name?is?Igathe

# %%
print("Kenya \n","Uganda \n","Tanzania \n","Congo \n")
# Out:
# Kenya
#  Uganda
#  Tanzania
#  Congo
